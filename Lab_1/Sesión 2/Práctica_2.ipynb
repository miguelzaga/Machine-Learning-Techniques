# %% [markdown]
# <a href="https://colab.research.google.com/github/hectormelo/Machine-Learning-Techniques/blob/main/Lab_1/Sesi%C3%B3n%202/Pr%C3%A1ctica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://bloqueneon.uniandes.edu.co/content/enforced/248650-202410_ISIS4219_01/Laboratorios.png" ><br>
# # Machine Learning Techniques - ISIS4219
#
# Primer semestre - 2024

# %% [markdown]
# ## Objetivos
#
# *   Identificar las difentes técnicas de pre-procesamiento de datos.
# *   Construir Pipelines para el procesamiento y entrenamiento del modelo.
# *   Visualizar un modelo construido en producción.

# %% [markdown]
# ## Problema
#
# Un supermercado ha decidido clasificar a sus clientes según su puntaje de consumo. Para ello, ha obtenido la información demográfica de varios de sus clientes y le ha pedido a sus expertos que clasifiquen el cliente según su historial de compras y la información recolectada. Luego de un consenso con los directivos del supermercado, se ha decidido clasificar estos clientes en tres diferentes grupos (*Low*, *Average*,  *High*). <br> <br>
# Luego de etiquetar estos datos, la gerencia le ha pedido que entrene un modelo de clasificación de sus clientes nuevos, teniendo en cuenta solo la información demográfica del cliente, con el fin de poder agrupar sus clientes y enviar las promociones construidas para ellos.

# %% [markdown]
# ### **1. Importando las librerias requeridas para el desarrollo del laboratorio**

# %% [markdown]
# Para la transformación de los datos, así como para el entrenamiento de los modelos y la visualización de los resultados, se importan las siguientes librerías:

# %% [markdown]
# **Nota:** Para asegurarse de tener las últimas versiones y todos los paquetes instalados que por lo general no vienen en Google Colab. pueden ejecutar la siguiente celda.

# %%
# %pip install pandas
# %pip install ydata-profiling
# %pip install scikit-learn
# %pip install sklearn_features
# %pip install matplotlib
# %pip install setuptools
# %pip install PyQt5

# %%
#Data management Libraries
import pandas as pd
import numpy as np
import sys
from ydata_profiling import ProfileReport


# Data Modeling Libraries
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, MinMaxScaler, MaxAbsScaler, LabelEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn_features.transformers import DataFrameSelector

from sklearn.compose import make_column_selector, ColumnTransformer


# Data visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns

#Save the model
from joblib import dump, load

# %% [markdown]
# ### **2. Perfilamiento y entendimiento de los datos**

# %% [markdown]
# #### **Lectura de los Datos**
# Primero, se leen los datos y se visualizan que se hayan leido correctamente.

# %%
data = pd.read_csv('./Train.csv')

data.head()
# Out:
#    Unnamed: 0      ID  Gender Ever_Married  Age Graduated     Profession  \
# 0           0  462809    Male           No   22        No     Healthcare
# 1           1  462643  Female          Yes   38       Yes       Engineer
# 2           2  466315  Female          Yes   67       Yes       Engineer
# 3           3  461735    Male          Yes   67       Yes         Lawyer
# 4           4  462669  Female          Yes   40       Yes  Entertainment
#
#    Work_Experience Spending_Score  Family_Size
# 0              1.0            Low          4.0
# 1              NaN        Average          3.0
# 2              1.0            Low          1.0
# 3              0.0           High          2.0
# 4              NaN           High          6.0

# %% [markdown]
# #### **Entendimiento de los Datos**
#
# Luego, vamos a obtener una vista rápida de los datos, para eso utilizaremos la herramienta PandasProfiling.

# %%
#ProfileReport(data)

# %% [markdown]
# Además, Vamos a relaizar visualizaciones individuales de variables de interés.

# %%
plt.bar(data['Spending_Score'].unique(),data['Spending_Score'].value_counts())
plt.title('Spending_Score')
plt.xlabel('Cant')
plt.ylabel('Spending_Score')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.tight_layout()
#sns.distplot(data['Age'])
sns.displot(np.array(data['Age']), kde=True)
# Out:
# /home/miguel/Documents/code/Machine-Learning-Techniques/.venv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### **3. Preparación de Datos**

# %% [markdown]
# #### **Separación de Datos**

# %% [markdown]
# Como se ve en Entendimeinto de los Datos, hay dos variables que realmente no nos están aportando información al problema, como lo son $Unnamed: 0$ y $ID$. <br>
# Además por el contexto del problema, nuestra idea será predecir el grupo al cual pertenecerá una nueva persona.

# %%
X = data.drop(['Unnamed: 0','ID','Spending_Score'],axis=1)
Y = data['Spending_Score']
X.head()
# Out:
#    Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0    Male           No   22        No     Healthcare              1.0
# 1  Female          Yes   38       Yes       Engineer              NaN
# 2  Female          Yes   67       Yes       Engineer              1.0
# 3    Male          Yes   67       Yes         Lawyer              0.0
# 4  Female          Yes   40       Yes  Entertainment              NaN
#
#    Family_Size
# 0          4.0
# 1          3.0
# 2          1.0
# 3          2.0
# 4          6.0

# %% [markdown]
# Así mismo, dado que nuestro algoritmo solo entiende números, se va a transformar nuestra variable categórica a una columna de números.

# %%
le = LabelEncoder()

le.fit(Y)

Y = le.transform(Y)
print(le.classes_)
Y
# Out:
# ['Average' 'High' 'Low']
# array([2, 0, 2, ..., 2, 2, 0])

# %% [markdown]
# #### **Transformación de Datos**

# %% [markdown]
# Debido a que la transformación de datos puede significar la construcción de varios pasos, como el manejo de faltantes, la normalización de datos, la transformación de variables categóricas, entre otros. Se pone en práctica el uso de [Pipeline](https://scikit-learn.org/stable/modules/compose.html), el cual es una herramienta de Sklearn que nos permite unir todos estos procesos y realizar de forma automática todas las transformaciones que necesitemos.

# %%
estimators = [('imputer', SimpleImputer(strategy='most_frequent')),
              ('encoder', OrdinalEncoder()),
              ]
pipe = Pipeline(estimators)
pipe
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('encoder', OrdinalEncoder())])

# %%
X_mod = pipe.fit_transform(X)
data_mod = pd.DataFrame(X_mod,columns=X.columns)
data_mod.head()
# Out:
#    Gender  Ever_Married   Age  Graduated  Profession  Work_Experience  \
# 0     1.0           0.0   4.0        0.0         5.0              1.0
# 1     0.0           1.0  18.0        1.0         2.0              1.0
# 2     0.0           1.0  44.0        1.0         2.0              1.0
# 3     1.0           1.0  44.0        1.0         7.0              0.0
# 4     0.0           1.0  20.0        1.0         3.0              1.0
#
#    Family_Size
# 0          3.0
# 1          2.0
# 2          0.0
# 3          1.0
# 4          5.0

# %%
estimators = [('imputer', SimpleImputer(strategy='most_frequent')),
              ('encoder', OrdinalEncoder()),
              ('normalize',MinMaxScaler()),
              ]
pipe2 = Pipeline(estimators)
pipe2
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('encoder', OrdinalEncoder()), ('normalize', MinMaxScaler())])

# %%
X_mod = pipe2.fit_transform(X)
data_mod = pd.DataFrame(X_mod,columns=X.columns)
data_mod.head()
# Out:
#    Gender  Ever_Married       Age  Graduated  Profession  Work_Experience  \
# 0     1.0           0.0  0.060606        0.0       0.625         0.071429
# 1     0.0           1.0  0.272727        1.0       0.250         0.071429
# 2     0.0           1.0  0.666667        1.0       0.250         0.071429
# 3     1.0           1.0  0.666667        1.0       0.875         0.000000
# 4     0.0           1.0  0.303030        1.0       0.375         0.071429
#
#    Family_Size
# 0        0.375
# 1        0.250
# 2        0.000
# 3        0.125
# 4        0.625

# %% [markdown]
# ### **4. Modelamiento**

# %% [markdown]
# Los Pipelines no solo sirven para construir los datos, transformarlos y adaptarlos. También sirven para conectar un modelo de aprendizaje, ya sea para predecir, clasificar o estimar.

# %%
estimators = [('preprocessing', pipe),
              ('clf',LogisticRegression(solver='liblinear')),
              ]
model = Pipeline(estimators)
model
# Out:
# Pipeline(steps=[('preprocessing',
#                  Pipeline(steps=[('imputer',
#                                   SimpleImputer(strategy='most_frequent')),
#                                  ('encoder', OrdinalEncoder())])),
#                 ('clf', LogisticRegression(solver='liblinear'))])

# %%
model.fit(X,Y)
# Out:
# Pipeline(steps=[('preprocessing',
#                  Pipeline(steps=[('imputer',
#                                   SimpleImputer(strategy='most_frequent')),
#                                  ('encoder', OrdinalEncoder())])),
#                 ('clf', LogisticRegression(solver='liblinear'))])

# %% [markdown]
# Construimos un segundo Pipeline para poder comparar rendimientos.

# %%
estimators = [('preprocessing', pipe2),
              ('clf', LogisticRegression(solver='liblinear')),
              ]
model2 = Pipeline(estimators)
model2
# Out:
# Pipeline(steps=[('preprocessing',
#                  Pipeline(steps=[('imputer',
#                                   SimpleImputer(strategy='most_frequent')),
#                                  ('encoder', OrdinalEncoder()),
#                                  ('normalize', MinMaxScaler())])),
#                 ('clf', LogisticRegression(solver='liblinear'))])

# %%
model2.fit(X,Y)
# Out:
# Pipeline(steps=[('preprocessing',
#                  Pipeline(steps=[('imputer',
#                                   SimpleImputer(strategy='most_frequent')),
#                                  ('encoder', OrdinalEncoder()),
#                                  ('normalize', MinMaxScaler())])),
#                 ('clf', LogisticRegression(solver='liblinear'))])

# %% [markdown]
# ### **5. Predicción**

# %% [markdown]
# #### **Predicción del clasificador**

# %% [markdown]
# Al igual que en la transformación de Datos, el conjunto de entrada de nuestro modelo serán los datos originales. Pero ahora al incluir un clasificador, el retornará la clase a la cual está prediciendo el dato.

# %%
pred1 = model.predict(X)
display(pred1)
pred2 = model2.predict(X)
display(pred2)
# Out:
# array([2, 0, 2, ..., 2, 2, 0])
# array([2, 0, 2, ..., 2, 2, 0])

# %% [markdown]
# Al obtener un modelo de clasificación y dado nuestras predicciones, podemos construir una matriz de confusión para nuestros modelos.
#
# La documentación de la función la encuentran en la [página de Sklearn](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.plot_confusion_matrix.html).

# %%
conf_matrix = confusion_matrix(Y, pred1)
disp = ConfusionMatrixDisplay(conf_matrix)
disp.plot(cmap='Blues', values_format='d')
# Añade etiquetas y muestra el gráfico
plt.title('Matriz de Confusión')
plt.show()


conf_matrix2 = confusion_matrix(Y, pred2)
disp = ConfusionMatrixDisplay(conf_matrix2)
disp.plot(cmap='Blues', values_format='d')
# Añade etiquetas y muestra el gráfico
plt.title('Matriz de Confusión 2')
plt.show()

# %% [markdown]
# Y por último, para comparar nuestros modelos, utilizaremos un reporte el cual nos muestra la precisión, la cobertura, y la métrica f1 de las predicciones de ambos modelos.

# %%
print('----------Reporte para el Modelo 1----------')
print(classification_report(Y,pred1,target_names=le.classes_))
print('----------Reporte para el Modelo 2----------')
print(classification_report(Y,pred2,target_names=le.classes_))
# Out:
# ----------Reporte para el Modelo 1----------
#               precision    recall  f1-score   support
#
#      Average       0.60      0.80      0.68      1974
#         High       0.63      0.43      0.51      1216
#          Low       0.89      0.84      0.86      4878
#
#     accuracy                           0.77      8068
#    macro avg       0.71      0.69      0.68      8068
# weighted avg       0.78      0.77      0.76      8068
#
# ----------Reporte para el Modelo 2----------
#               precision    recall  f1-score   support
#
#      Average       0.59      0.80      0.68      1974
#         High       0.63      0.42      0.51      1216
#          Low       0.89      0.84      0.86      4878
#
#     accuracy                           0.77      8068
#    macro avg       0.70      0.69      0.68      8068
# weighted avg       0.78      0.77      0.76      8068

# %% [markdown]
# #### **Selección de Hiperparámetros**

# %% [markdown]
# Otra gran ventaja de los Pipeline, es que nos permite seleccionar los hiperparámetros de construcción para obtener nuestro mejor modelo. Esta construcción la realiza a través de [GridSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html). Y nos permite escoger los hiperparámetros de cada una de nuestras etapas del Pipeline. También podemos escoger si decidimos utilizar un paso o no.

# %%
ct = ColumnTransformer([
       ('num', SimpleImputer(strategy='mean'),
       make_column_selector(dtype_include=np.number)),
       ('cat',
       SimpleImputer(strategy='most_frequent'),
       make_column_selector(dtype_include=object))])

estimators = [('imputer', ct),
              ('encoder', OrdinalEncoder()),
              ('normalize',MaxAbsScaler()),
              ('clf', LogisticRegression(solver='liblinear')),
              ]
pipe = Pipeline(estimators)

param_grid = dict(imputer__num__strategy=['mean', 'median'],
                  imputer__cat__strategy=['most_frequent', 'constant'],
                  encoder=[OrdinalEncoder(), OneHotEncoder()],
                  normalize=['passthrough', MaxAbsScaler()])

grid_search = GridSearchCV(pipe, param_grid=param_grid,cv=5,verbose=3,scoring='accuracy')

grid_search.fit(X,Y.ravel())
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=passthrough;, score=0.758 total time=   0.1s
# [CV 2/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=passthrough;, score=0.747 total time=   0.1s
# [CV 3/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=passthrough;, score=0.758 total time=   0.1s
# [CV 4/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=passthrough;, score=0.743 total time=   0.1s
# [CV 5/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=passthrough;, score=0.764 total time=   0.1s
# [CV 1/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.758 total time=   0.1s
# [CV 2/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.747 total time=   0.1s
# [CV 3/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.758 total time=   0.1s
# [CV 4/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.741 total time=   0.1s
# [CV 5/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.761 total time=   0.1s
# [CV 1/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=passthrough;, score=0.765 total time=   0.1s
# [CV 2/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=passthrough;, score=0.753 total time=   0.1s
# [CV 3/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=passthrough;, score=0.766 total time=   0.1s
# [CV 4/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=passthrough;, score=0.749 total time=   0.1s
# [CV 5/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=passthrough;, score=0.777 total time=   0.1s
# [CV 1/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.766 total time=   0.1s
# [CV 2/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.753 total time=   0.1s
# [CV 3/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.766 total time=   0.1s
# [CV 4/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.743 total time=   0.1s
# [CV 5/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.777 total time=   0.1s
# [CV 1/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=passthrough;, score=0.745 total time=   0.1s
# [CV 2/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=passthrough;, score=0.734 total time=   0.1s
# [CV 3/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=passthrough;, score=0.742 total time=   0.1s
# [CV 4/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=passthrough;, score=0.726 total time=   0.1s
# [CV 5/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=passthrough;, score=0.749 total time=   0.1s
# [CV 1/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.742 total time=   0.1s
# [CV 2/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.732 total time=   0.1s
# [CV 3/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.742 total time=   0.1s
# [CV 4/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.723 total time=   0.1s
# [CV 5/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.745 total time=   0.1s
# [CV 1/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=passthrough;, score=0.751 total time=   0.1s
# [CV 2/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=passthrough;, score=0.733 total time=   0.1s
# [CV 3/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=passthrough;, score=0.749 total time=   0.1s
# [CV 4/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=passthrough;, score=0.732 total time=   0.1s
# [CV 5/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=passthrough;, score=0.756 total time=   0.1s
# [CV 1/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.750 total time=   0.1s
# [CV 2/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.733 total time=   0.1s
# [CV 3/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.747 total time=   0.1s
# [CV 4/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.727 total time=   0.1s
# [CV 5/5] END encoder=OrdinalEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.750 total time=   0.1s
# [CV 1/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=passthrough;, score=0.803 total time=   0.1s
# [CV 2/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=passthrough;, score=0.800 total time=   0.1s
# [CV 3/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=passthrough;, score=0.816 total time=   0.1s
# [CV 4/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=passthrough;, score=0.802 total time=   0.1s
# [CV 5/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=passthrough;, score=0.820 total time=   0.1s
# [CV 1/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.803 total time=   0.1s
# [CV 2/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.800 total time=   0.1s
# [CV 3/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.816 total time=   0.1s
# [CV 4/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.802 total time=   0.1s
# [CV 5/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.820 total time=   0.1s
# [CV 1/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=passthrough;, score=0.795 total time=   0.1s
# [CV 2/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=passthrough;, score=0.796 total time=   0.1s
# [CV 3/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=passthrough;, score=0.814 total time=   0.1s
# [CV 4/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=passthrough;, score=0.802 total time=   0.1s
# [CV 5/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=passthrough;, score=0.812 total time=   0.1s
# [CV 1/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.795 total time=   0.1s
# [CV 2/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.796 total time=   0.1s
# [CV 3/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.814 total time=   0.1s
# [CV 4/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.802 total time=   0.1s
# [CV 5/5] END encoder=OneHotEncoder(), imputer__cat__strategy=most_frequent, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.812 total time=   0.1s
# [CV 1/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=passthrough;, score=0.800 total time=   0.1s
# [CV 2/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=passthrough;, score=0.800 total time=   0.1s
# [CV 3/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=passthrough;, score=0.814 total time=   0.1s
# [CV 4/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=passthrough;, score=0.800 total time=   0.1s
# [CV 5/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=passthrough;, score=0.820 total time=   0.1s
# [CV 1/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.800 total time=   0.1s
# [CV 2/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.800 total time=   0.1s
# [CV 3/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.814 total time=   0.1s
# [CV 4/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.800 total time=   0.1s
# [CV 5/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=mean, normalize=MaxAbsScaler();, score=0.820 total time=   0.1s
# [CV 1/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=passthrough;, score=0.792 total time=   0.1s
# [CV 2/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=passthrough;, score=0.796 total time=   0.1s
# [CV 3/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=passthrough;, score=0.813 total time=   0.1s
# [CV 4/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=passthrough;, score=0.799 total time=   0.1s
# [CV 5/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=passthrough;, score=0.812 total time=   0.1s
# [CV 1/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.792 total time=   0.1s
# [CV 2/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.796 total time=   0.1s
# [CV 3/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.813 total time=   0.1s
# [CV 4/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.799 total time=   0.1s
# [CV 5/5] END encoder=OneHotEncoder(), imputer__cat__strategy=constant, imputer__num__strategy=median, normalize=MaxAbsScaler();, score=0.812 total time=   0.1s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('imputer',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          SimpleImputer(),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x7fa624060ee0>),
#                                                                         ('cat',
#                                                                          SimpleImputer(strategy='most_frequent'),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x7fa624061b40>)])),
#                                        ('encoder', OrdinalEncoder()),
#                                        ('normalize', MaxAbsScaler()),
#                                        ('clf',
#                                         LogisticRegression(solver='liblinear'))]),
#              param_grid={'encoder': [OrdinalEncoder(), OneHotEncoder()],
#                          'imputer__cat__strategy': ['most_frequent',
#                                                     'constant'],
#                          'imputer__num__strategy': ['mean', 'median'],
#                          'normalize': ['passthrough', MaxAbsScaler()]},
#              scoring='accuracy', verbose=3)

# %% [markdown]
# Ya que nuestro GridSearch entrenó todos los modelos, ahora podemos visualizar cuales fueron nuestros mejores hiperparámetros seleccionados, nuestro mejor modelo y una tabla de resultados de todos los modelos evaluados.

# %%
print(grid_search.best_params_)
# Out:
# {'encoder': OneHotEncoder(), 'imputer__cat__strategy': 'most_frequent', 'imputer__num__strategy': 'mean', 'normalize': 'passthrough'}

# %%
resultados = pd.DataFrame(grid_search.cv_results_)
display(resultados)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.099445      0.003597         0.010558        0.000984
# 1        0.071364      0.006908         0.010924        0.002055
# 2        0.096356      0.004921         0.010938        0.001793
# 3        0.071685      0.003769         0.009816        0.001965
# 4        0.087270      0.006874         0.009250        0.001938
# 5        0.063996      0.006504         0.009629        0.002155
# 6        0.091092      0.007128         0.009471        0.001692
# 7        0.062934      0.007257         0.009085        0.001184
# 8        0.092303      0.012631         0.011797        0.001801
# 9        0.092999      0.009794         0.010896        0.001877
# 10       0.095111      0.017247         0.011061        0.001592
# 11       0.103571      0.004309         0.012637        0.001886
# 12       0.085731      0.002680         0.012023        0.000973
# 13       0.085362      0.002209         0.011081        0.001581
# 14       0.092231      0.007612         0.012466        0.002220
# 15       0.101954      0.009616         0.013036        0.001275
#
#        param_encoder param_imputer__cat__strategy  \
# 0   OrdinalEncoder()                most_frequent
# 1   OrdinalEncoder()                most_frequent
# 2   OrdinalEncoder()                most_frequent
# 3   OrdinalEncoder()                most_frequent
# 4   OrdinalEncoder()                     constant
# 5   OrdinalEncoder()                     constant
# 6   OrdinalEncoder()                     constant
# 7   OrdinalEncoder()                     constant
# 8    OneHotEncoder()                most_frequent
# 9    OneHotEncoder()                most_frequent
# 10   OneHotEncoder()                most_frequent
# 11   OneHotEncoder()                most_frequent
# 12   OneHotEncoder()                     constant
# 13   OneHotEncoder()                     constant
# 14   OneHotEncoder()                     constant
# 15   OneHotEncoder()                     constant
#
#    param_imputer__num__strategy param_normalize  \
# 0                          mean     passthrough
# 1                          mean  MaxAbsScaler()
# 2                        median     passthrough
# 3                        median  MaxAbsScaler()
# 4                          mean     passthrough
# 5                          mean  MaxAbsScaler()
# 6                        median     passthrough
# 7                        median  MaxAbsScaler()
# 8                          mean     passthrough
# 9                          mean  MaxAbsScaler()
# 10                       median     passthrough
# 11                       median  MaxAbsScaler()
# 12                         mean     passthrough
# 13                         mean  MaxAbsScaler()
# 14                       median     passthrough
# 15                       median  MaxAbsScaler()
#
#                                                params  split0_test_score  \
# 0   {'encoder': OrdinalEncoder(), 'imputer__cat__s...           0.757745
# 1   {'encoder': OrdinalEncoder(), 'imputer__cat__s...           0.758364
# 2   {'encoder': OrdinalEncoder(), 'imputer__cat__s...           0.764560
# 3   {'encoder': OrdinalEncoder(), 'imputer__cat__s...           0.765799
# 4   {'encoder': OrdinalEncoder(), 'imputer__cat__s...           0.744734
# 5   {'encoder': OrdinalEncoder(), 'imputer__cat__s...           0.742255
# 6   {'encoder': OrdinalEncoder(), 'imputer__cat__s...           0.750929
# 7   {'encoder': OrdinalEncoder(), 'imputer__cat__s...           0.749690
# 8   {'encoder': OneHotEncoder(), 'imputer__cat__st...           0.802974
# 9   {'encoder': OneHotEncoder(), 'imputer__cat__st...           0.802974
# 10  {'encoder': OneHotEncoder(), 'imputer__cat__st...           0.794919
# 11  {'encoder': OneHotEncoder(), 'imputer__cat__st...           0.794919
# 12  {'encoder': OneHotEncoder(), 'imputer__cat__st...           0.799876
# 13  {'encoder': OneHotEncoder(), 'imputer__cat__st...           0.799876
# 14  {'encoder': OneHotEncoder(), 'imputer__cat__st...           0.792441
# 15  {'encoder': OneHotEncoder(), 'imputer__cat__st...           0.792441
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.746592           0.758364           0.743335
# 1            0.747212           0.757745           0.741476
# 2            0.752788           0.766419           0.748915
# 3            0.752788           0.766419           0.742715
# 4            0.733581           0.741636           0.725976
# 5            0.732342           0.741636           0.723497
# 6            0.732962           0.749071           0.731556
# 7            0.732962           0.746592           0.727216
# 8            0.800496           0.815985           0.802232
# 9            0.800496           0.815985           0.802232
# 10           0.796159           0.813507           0.802232
# 11           0.796159           0.813507           0.802232
# 12           0.799876           0.813507           0.799752
# 13           0.799876           0.813507           0.799752
# 14           0.796159           0.812887           0.799132
# 15           0.796159           0.812887           0.799132
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.764414         0.754090        0.007875               11
# 1            0.760694         0.753098        0.007440               12
# 2            0.777433         0.762023        0.010201                9
# 3            0.776813         0.760907        0.011867               10
# 4            0.748915         0.738968        0.008211               15
# 5            0.745195         0.736985        0.008004               16
# 6            0.756355         0.744174        0.010029               13
# 7            0.750155         0.741323        0.009431               14
# 8            0.819591         0.808255        0.007907                1
# 9            0.819591         0.808255        0.007907                1
# 10           0.811531         0.803670        0.007663                5
# 11           0.811531         0.803670        0.007663                5
# 12           0.820211         0.806644        0.008605                3
# 13           0.820211         0.806644        0.008605                3
# 14           0.811531         0.802430        0.008273                7
# 15           0.811531         0.802430        0.008273                7

# %% [markdown]
# Y por último, guardaremos nuestro modelo para utilizarlo después.

# %%
dump(grid_search.best_estimator_, 'my_model.joblib')

model = load('my_model.joblib')

pred1 = model.predict(X)
print('----------Reporte para el Mejor Modelo----------')
print(classification_report(Y,pred1,target_names=le.classes_))
# Out:
# ----------Reporte para el Mejor Modelo----------
#               precision    recall  f1-score   support
#
#      Average       0.63      0.90      0.74      1974
#         High       0.74      0.62      0.68      1216
#          Low       0.96      0.83      0.89      4878
#
#     accuracy                           0.82      8068
#    macro avg       0.78      0.78      0.77      8068
# weighted avg       0.84      0.82      0.82      8068

# %% [markdown]
# ### **6. Validación**

# %% [markdown]
# Para la validación, utilizaremos un nuevo conjunto de datos que nos servirán como Conjunto Test. Como se han dado cuenta, en ningún momento le he pasado estos nuevos datos durante la etepa de entrenameinto

# %%
test = pd.read_csv('https://raw.githubusercontent.com/hectormelo/Machine-Learning-Techniques/main/Lab_1/Sesi%C3%B3n%202/Test.csv')
X_test = test.drop(['Unnamed: 0','ID','Spending_Score'],axis=1)
Y_test = le.transform(test['Spending_Score'])

# %%
y_pred=model.predict(X_test)

print('----------Reporte para el Mejor Modelo con datos nuevos----------')
print(classification_report(Y_test,y_pred,target_names=le.classes_))
# Out:
# ----------Reporte para el Mejor Modelo con datos nuevos----------
#               precision    recall  f1-score   support
#
#      Average       0.62      0.89      0.73       625
#         High       0.72      0.62      0.67       386
#          Low       0.95      0.83      0.88      1616
#
#     accuracy                           0.81      2627
#    macro avg       0.77      0.78      0.76      2627
# weighted avg       0.84      0.81      0.82      2627

# %% [markdown]
# Y ahora, construiremos un dato propio para ver como se comporta nuestro modelo.

# %%
Gender = 'Female'
Ever_Married = 'Yes'
Age = 36
Graduated = 'Yes'
Profession = np.nan
Work_Experience = 0
Family_Size = 3
row = [Gender,Ever_Married,Age,Graduated,Profession,Work_Experience,Family_Size]

input = pd.DataFrame([row],columns=X.columns)

resp = model.predict(input)

print(model.predict_proba(input))

le.inverse_transform(resp)[0]
# Out:
# [[0.69783857 0.10162467 0.20053677]]
# 'Average'

# %% [markdown]
# Para desarrollar:
#
# - Para este caso, solo se estabelcieron como hiperparámetros, el preprocesamiento de los datos, ¿Cuáles serían los hiperparámetros de la Regresión Logística? ¿Cual sería el mejor modelo que se podría construir?
# - Los expertos del supermercado le han sugerido utilizar el algoritmo [KNN-Clasifier](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html), ¿Se obtuvo un mejor modelo?
# - Se dieron cuenta que sus clientes más representativos son aquellos que están clasificados en la clase 'High', por eso quieren identificar a todos sus clientes potenciales para ofrecerles descuentos. Pueden aceptar que algún cliente que no esté en esta categoría reciba la oferta, pero es importante que todos los clientes (o su gran mayoría) sea capaz de recibir esta oferta. ¿Cual sería el mejor modelo para este caso?

# %% [markdown]
# ### Desarrollo
# - Los hiperparámetros de la Regresión Logística serían aquellos relacionados con la **regularización**
#
# En scikit se pueden modificar con "Solvers":
#
# ![image.png](attachment:image.png)

# %%
from sklearn.linear_model import LogisticRegressionCV # automáticamente escoge el mejor solver

# %%
pipe3 = Pipeline([
    ('imputer', ct),
    ('encoder', OneHotEncoder()),
    ('classifier', LogisticRegressionCV(Cs=[0.01, 0.1, 1, 10])) # diferentes términos de regularización (lambda)
])
pipe3
# Out:
# Pipeline(steps=[('imputer',
#                  ColumnTransformer(transformers=[('num', SimpleImputer(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fa624060ee0>),
#                                                  ('cat',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fa624061b40>)])),
#                 ('encoder', OneHotEncoder()),
#                 ('classifier', LogisticRegressionCV(Cs=[0.01, 0.1, 1, 10]))])

# %%
pipe3.fit(X, Y)
# Out:
# Pipeline(steps=[('imputer',
#                  ColumnTransformer(transformers=[('num', SimpleImputer(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fa624060ee0>),
#                                                  ('cat',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fa624061b40>)])),
#                 ('encoder', OneHotEncoder()),
#                 ('classifier', LogisticRegressionCV(Cs=[0.01, 0.1, 1, 10]))])

# %%
y_pred=pipe3.predict(X_test)

print('----------Reporte para el Modelo con LogisticRegressionCV----------')
print(classification_report(Y_test,y_pred,target_names=le.classes_))
# Out:
# ----------Reporte para el Modelo con LogisticRegressionCV----------
#               precision    recall  f1-score   support
#
#      Average       0.62      0.90      0.73       625
#         High       0.72      0.61      0.66       386
#          Low       0.96      0.83      0.89      1616
#
#     accuracy                           0.81      2627
#    macro avg       0.77      0.78      0.76      2627
# weighted avg       0.84      0.81      0.82      2627

# %% [markdown]
# - KNN-Clasifier
#
# No se ve una mejora en la predicción

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
pipe4 = Pipeline([
    ('imputer', ct),
    ('encoder', OneHotEncoder()),
    ('classifier', KNeighborsClassifier(n_neighbors=3))
])
pipe4
# Out:
# Pipeline(steps=[('imputer',
#                  ColumnTransformer(transformers=[('num', SimpleImputer(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fa624060ee0>),
#                                                  ('cat',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fa624061b40>)])),
#                 ('encoder', OneHotEncoder()),
#                 ('classifier', KNeighborsClassifier(n_neighbors=3))])

# %%
pipe4.fit(X, Y)
# Out:
# Pipeline(steps=[('imputer',
#                  ColumnTransformer(transformers=[('num', SimpleImputer(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fa624060ee0>),
#                                                  ('cat',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fa624061b40>)])),
#                 ('encoder', OneHotEncoder()),
#                 ('classifier', KNeighborsClassifier(n_neighbors=3))])

# %%
y_pred=pipe4.predict(X_test)

print('----------Reporte para el Modelo con KNeighborsClassifier----------')
print(classification_report(Y_test,y_pred,target_names=le.classes_))
# Out:
# ----------Reporte para el Modelo con KNeighborsClassifier----------
#               precision    recall  f1-score   support
#
#      Average       0.60      0.73      0.66       625
#         High       0.70      0.56      0.62       386
#          Low       0.89      0.85      0.87      1616
#
#     accuracy                           0.78      2627
#    macro avg       0.73      0.71      0.71      2627
# weighted avg       0.79      0.78      0.78      2627

# %% [markdown]
# - Si nuestra prioridad es que los clientes 'High' reciban la oferta (sin importar tanto que le llegue la oferta a otros), tenemos que priorizar 'recall', por lo tanto el mejor modelo sería el modelo 3, el que se hizo con GridSearchCV. Ya que tiene un 'recall' de 0.62 para la categoría 'High'
